# %%
import threading
import time

def task(name):
    print(f"Task {name}: Starting")
    time.sleep(2)
    print(f"Task {name}: Completed")

    t1 = threading.Thread(target=task, args=('ram',))
    t2 = threading.Thread(target=task, args=('shyam',))

    start = time.time()

    t1.start()
    t2.start()

    t1.join()
    t2.join()

    print(f"All tasks completed in {time.time() - start} seconds")

task('chandu')
# Out:
# Task chandu: Starting
# Task chandu: Completed

# %%
import threading
import time

def print_numbers():
    for i in range(5):
        time.sleep(2)
        print(f"CPU Task iteration {i}")

def print_letters():
    for letter in 'abcde':
        time.sleep(2)
        print(f"Letter: {letter}")

t1 = threading.Thread(target=print_numbers)
t2 = threading.Thread(target=print_letters)

t = time.time()

t1.start()
t2.start()

t1.join()
t2.join()
# Out:
# CPU Task iteration 0
# Letter: a
# Letter: b
# CPU Task iteration 1
# Letter: cCPU Task iteration 2
#
# CPU Task iteration 3Letter: d
#
# Letter: e
# CPU Task iteration 4
